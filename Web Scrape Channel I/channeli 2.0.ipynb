# %%
#Instead of branchname I have used company as the name of list only affecting the column name 

from selenium import webdriver 
driver = webdriver.Chrome("C:\\Users\\NISHANT\\Desktop\\chromedriver_win32\\chromedriver.exe")
driver.get("https://channeli.in/placement/results/branch/")
driver.find_element_by_name("username").send_keys("14118062")
driver.find_element_by_name("password").send_keys("38154063")
driver.find_element_by_id("sign_in_button").click()
company = []
selected = []

# %%
#reach a location from which data has to be extracted
rows = driver.find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')
for row in rows:
    print(row.text)
# Out:
# 1 MSc Applied Geology 2 View View
# 2 IMSc Applied Mathematics 11 View View
# 3 B.Arch. Architecture and Planning 13 View View
# 4 M.Arch. Architecture and Planning 10 View View
# 5 IDD B. Tech. (Chemical Engineering) and M. Tech. (Hydrocarbon Engineering) 11 View View
# 6 IDD B. Tech. (Computer Science & Engineering) and M. Tech. (Information Technology) 2 View View
# 7 IDD B. Tech. (Electrical Engineering) and M.Tech. (Power Electronics) 10 View View
# 8 IDD B. Tech. (Electronics & Communication Engineering) and M. Tech. (Wireless Communication) 15 View View
# 9 IDD B. Tech. (Process Engineering) and M.B.A. 9 View View
# 10 B.Tech. Biotechnology 14 View View
# 11 MSc Biotechnology 1 View View
# 12 M.Tech. CAD,CAM & Robotics 4 View View
# 13 B.Tech. Chemical Engineering 49 View View
# 14 IMSc Chemistry 2 View View
# 15 B.Tech. Civil Engineering 36 View View
# 16 IDD Civil Engineering with specialisation in Structures 5 View View
# 17 M.Tech. Communication Systems 2 View View
# 18 M.Tech. Computer Science & Engineering 36 View View
# 19 B.Tech. Computer Science and Engineering 69 View View
# 20 M.Tech. Electric Drives and Power Electronics 2 View View
# 21 B.Tech. Electrical Engineering 92 View View
# 22 B.Tech. Electronics & Communication Engineering 66 View View
# 23 IMT Geological Technology 12 View View
# 24 IMT Geophysical Technology 15 View View
# 25 MSc M.Sc. Mathematics 1 View View
# 26 M.Tech. Machine Design Engineering 4 View View
# 27 MBA Management and Business Administration 47 View View
# 28 MURP Master of Urban and Rural Planning 1 View View
# 29 B.Tech. Mechanical Engineering 38 View View
# 30 B.Tech. Metallurgical & Materials Engineering 37 View View
# 31 IDD Metallurgy Dual 7 View View
# 32 M.Tech. Micro Electronic and VLSI 4 View View
# 33 IMSc Physics 3 View View
# 34 B.Tech. Polymer Science and Technology 1 View View
# 35 M.Tech. Power System Engineering 3 View View
# 36 B.Tech. Production and Industrial Engineering 25 View View
# 37 M.Tech. Pulp & Paper Engineering 1 View View
# 38 M.Tech. RF and Microwave Engineering 2 View View
# 39 M.Tech. Solid State Electronic Materials 1 View View
# 40 M.Tech. Structural Dynamics 8 View View
# 41 M.Tech. Structural Engineering 4 View View
# 42 M.Tech. System and Control 1 View View
# 43 M.Tech. Thermal Engineering 1 View View
# 44 M.Tech. Transportation Engineering 2 View View

# %%
rows = driver.find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')
for row in rows:
    print(row.text)
    k=row.find_elements_by_tag_name('td')
    for i in row.find_elements_by_tag_name('td'):
        print(i.text)
# Out:
# 1 MSc Applied Geology 2 View View
# 1
# MSc
# Applied Geology
# 2
# View
# View
# 2 IMSc Applied Mathematics 11 View View
# 2
# IMSc
# Applied Mathematics
# 11
# View
# View
# 3 B.Arch. Architecture and Planning 13 View View
# 3
# B.Arch.
# Architecture and Planning
# 13
# View
# View
# 4 M.Arch. Architecture and Planning 10 View View
# 4
# M.Arch.
# Architecture and Planning
# 10
# View
# View
# 5 IDD B. Tech. (Chemical Engineering) and M. Tech. (Hydrocarbon Engineering) 11 View View
# 5
# IDD
# B. Tech. (Chemical Engineering) and M. Tech. (Hydrocarbon Engineering)
# 11
# View
# View
# 6 IDD B. Tech. (Computer Science & Engineering) and M. Tech. (Information Technology) 2 View View
# 6
# IDD
# B. Tech. (Computer Science & Engineering) and M. Tech. (Information Technology)
# 2
# View
# View
# 7 IDD B. Tech. (Electrical Engineering) and M.Tech. (Power Electronics) 10 View View
# 7
# IDD
# B. Tech. (Electrical Engineering) and M.Tech. (Power Electronics)
# 10
# View
# View
# 8 IDD B. Tech. (Electronics & Communication Engineering) and M. Tech. (Wireless Communication) 15 View View
# 8
# IDD
# B. Tech. (Electronics & Communication Engineering) and M. Tech. (Wireless Communication)
# 15
# View
# View
# 9 IDD B. Tech. (Process Engineering) and M.B.A. 9 View View
# 9
# IDD
# B. Tech. (Process Engineering) and M.B.A.
# 9
# View
# View
# 10 B.Tech. Biotechnology 14 View View
# 10
# B.Tech.
# Biotechnology
# 14
# View
# View
# 11 MSc Biotechnology 1 View View
# 11
# MSc
# Biotechnology
# 1
# View
# View
# 12 M.Tech. CAD,CAM & Robotics 4 View View
# 12
# M.Tech.
# CAD,CAM & Robotics
# 4
# View
# View
# 13 B.Tech. Chemical Engineering 49 View View
# 13
# B.Tech.
# Chemical Engineering
# 49
# View
# View
# 14 IMSc Chemistry 2 View View
# 14
# IMSc
# Chemistry
# 2
# View
# View
# 15 B.Tech. Civil Engineering 36 View View
# 15
# B.Tech.
# Civil Engineering
# 36
# View
# View
# 16 IDD Civil Engineering with specialisation in Structures 5 View View
# 16
# IDD
# Civil Engineering with specialisation in Structures
# 5
# View
# View
# 17 M.Tech. Communication Systems 2 View View
# 17
# M.Tech.
# Communication Systems
# 2
# View
# View
# 18 M.Tech. Computer Science & Engineering 36 View View
# 18
# M.Tech.
# Computer Science & Engineering
# 36
# View
# View
# 19 B.Tech. Computer Science and Engineering 69 View View
# 19
# B.Tech.
# Computer Science and Engineering
# 69
# View
# View
# 20 M.Tech. Electric Drives and Power Electronics 2 View View
# 20
# M.Tech.
# Electric Drives and Power Electronics
# 2
# View
# View
# 21 B.Tech. Electrical Engineering 92 View View
# 21
# B.Tech.
# Electrical Engineering
# 92
# View
# View
# 22 B.Tech. Electronics & Communication Engineering 66 View View
# 22
# B.Tech.
# Electronics & Communication Engineering
# 66
# View
# View
# 23 IMT Geological Technology 12 View View
# 23
# IMT
# Geological Technology
# 12
# View
# View
# 24 IMT Geophysical Technology 15 View View
# 24
# IMT
# Geophysical Technology
# 15
# View
# View
# 25 MSc M.Sc. Mathematics 1 View View
# 25
# MSc
# M.Sc. Mathematics
# 1
# View
# View
# 26 M.Tech. Machine Design Engineering 4 View View
# 26
# M.Tech.
# Machine Design Engineering
# 4
# View
# View
# 27 MBA Management and Business Administration 47 View View
# 27
# MBA
# Management and Business Administration
# 47
# View
# View
# 28 MURP Master of Urban and Rural Planning 1 View View
# 28
# MURP
# Master of Urban and Rural Planning
# 1
# View
# View
# 29 B.Tech. Mechanical Engineering 38 View View
# 29
# B.Tech.
# Mechanical Engineering
# 38
# View
# View
# 30 B.Tech. Metallurgical & Materials Engineering 37 View View
# 30
# B.Tech.
# Metallurgical & Materials Engineering
# 37
# View
# View
# 31 IDD Metallurgy Dual 7 View View
# 31
# IDD
# Metallurgy Dual
# 7
# View
# View
# 32 M.Tech. Micro Electronic and VLSI 4 View View
# 32
# M.Tech.
# Micro Electronic and VLSI
# 4
# View
# View
# 33 IMSc Physics 3 View View
# 33
# IMSc
# Physics
# 3
# View
# View
# 34 B.Tech. Polymer Science and Technology 1 View View
# 34
# B.Tech.
# Polymer Science and Technology
# 1
# View
# View
# 35 M.Tech. Power System Engineering 3 View View
# 35
# M.Tech.
# Power System Engineering
# 3
# View
# View
# 36 B.Tech. Production and Industrial Engineering 25 View View
# 36
# B.Tech.
# Production and Industrial Engineering
# 25
# View
# View
# 37 M.Tech. Pulp & Paper Engineering 1 View View
# 37
# M.Tech.
# Pulp & Paper Engineering
# 1
# View
# View
# 38 M.Tech. RF and Microwave Engineering 2 View View
# 38
# M.Tech.
# RF and Microwave Engineering
# 2
# View
# View
# 39 M.Tech. Solid State Electronic Materials 1 View View
# 39
# M.Tech.
# Solid State Electronic Materials
# 1
# View
# View
# 40 M.Tech. Structural Dynamics 8 View View
# 40
# M.Tech.
# Structural Dynamics
# 8
# View
# View
# 41 M.Tech. Structural Engineering 4 View View
# 41
# M.Tech.
# Structural Engineering
# 4
# View
# View
# 42 M.Tech. System and Control 1 View View
# 42
# M.Tech.
# System and Control
# 1
# View
# View
# 43 M.Tech. Thermal Engineering 1 View View
# 43
# M.Tech.
# Thermal Engineering
# 1
# View
# View
# 44 M.Tech. Transportation Engineering 2 View View
# 44
# M.Tech.
# Transportation Engineering
# 2
# View
# View

# %%
import pandas as pd 
from pandas import DataFrame

# %%
rows = driver.find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')
for row in rows:
        k=row.find_elements_by_tag_name('td')
        company.append(k[2].text)
        selected.append(k[3].text)

# %%
df = pd.DataFrame({'Company':company,'selected':selected})

# %%
df.head()
# Out:
#                                              Company selected
# 0                                    Applied Geology        2
# 1                                Applied Mathematics       11
# 2                          Architecture and Planning       13
# 3                          Architecture and Planning       10
# 4  B. Tech. (Chemical Engineering) and M. Tech. (...       11

# %%
df.to_csv("selectednum.csv",index=False)

# %%
driver.get("https://channeli.in/placement/results/2016/company/")

# %%
comp = []
selected2 = []

# %%
rows2 = driver.find_element_by_tag_name('tbody').find_elements_by_tag_name('tr')
for row in rows2:
        m=row.find_elements_by_tag_name('td')
        comp.append(m[1].text)
        selected2.append(m[2].text)

# %%
df2 = pd.DataFrame({'Company':comp,'Selected':selected2})

# %%
df2
# Out:
#                                                Company Selected
# 0                   Accenture Services Pvt. Ltd. (PPO)        1
# 1                                  Adobe Systems (PPO)       13
# 2                                     Affine Analytics        7
# 3                                          Alethe Labs        2
# 4                                               Amazon        5
# 5    Amazon Development Centre (India) Pvt. Ltd. (PPO)        5
# 6                                     American Express        5
# 7                         American Express India (PPO)        4
# 8                               Analytics Quotient MBA        3
# 9                                    Applied Materials        1
# 10                                       ASC Infratech        3
# 11                                        Atkins India        3
# 12                               Axtria India Pvt. Ltd        5
# 13             B & S Engineering Consultants Pvt. Ltd.        1
# 14                                          Bajaj Auto        1
# 15                  BeeHyv Software Solutions Pvt. Ltd        5
# 16                                       Bharti Airtel        3
# 17                                             Bidgely        2
# 18                                         Bristlecone        2
# 19                            Busigence: Data Engineer        1
# 20                                               C-Dot        3
# 21                                           Capgemini        9
# 22        Capital One Services (India) Pvt. Ltd. (PPO)        2
# 23        Center For Development of Advanced Computing        3
# 24   CGI Information Systems And Management Consult...        6
# 25                                               Chegg        4
# 26             Citicorp Services India Pvt. Ltd. (PPO)        4
# 27                                           CitiGroup       11
# 28       Cognizant Technology Solutions( Data analyst)        9
# 29            Cognizant technology solutions(Software)       16
# ..                                                 ...      ...
# 132                                 Stat Decision Labs        1
# 133                                             Suzlon        1
# 134                           Tata Communications Ltd.        2
# 135            Tata Consultancy Services Ltd.(Digital)        1
# 136           Tata Consultancy Services Ltd.(Research)        1
# 137                                 Tata Motors for UG       11
# 138                                   Tata Motors Ltd.        3
# 139                              TATA Steel Ltd. (PPO)        8
# 140                                            TCS-BPS        4
# 141                                    Tesco Bengaluru        3
# 142                            Texas Instruments (PPO)        4
# 143                                       Thermofisher        4
# 144                     Thornton Tomasetti (India) LLP        1
# 145      TransBitTechnologies Software Private Limited        4
# 146                                          Treebo BA        6
# 147                                 UnitedHealth Group        2
# 148                                 vConstruct Pvt.Ltd        1
# 149                                            Vedanta        2
# 150                                            Veritas        4
# 151                        Virtusa Consulting Services        9
# 152                                    Visa Inc. (PPO)        4
# 153                       Vizury Interactive Solutions        1
# 154                                             VMWare        6
# 155                                       Walmart Labs        4
# 156                                              Wipro       16
# 157                                Wipro Limited (PPO)        5
# 158                          Works Applications Co Ltd        6
# 159                      Zemoso Technologies Pvt. Ltd.        6
# 160  ZS Associates India Pvt Ltd: Data Science Asso...        1
# 161                  ZS Associates Pvt. Ltd.: Business        7
#
# [162 rows x 2 columns]

# %%
# df2.to_csv("selectedcomp1.csv",index=False)
